# %%
# Linear Regression

# %%
import pandas as pd
import numpy as np  
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split  
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error

# %%
lr=LinearRegression()

# %%
iris=pd.read_csv('./datasets/iris.csv')

# %%
iris[iris['SepalWidthCm']>4]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa
# 32  33            5.2           4.1            1.5           0.1  Iris-setosa
# 33  34            5.5           4.2            1.4           0.2  Iris-setosa

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris[iris['PetalWidthCm']>2]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 102  103            7.1           3.0            5.9           2.1
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 109  110            7.2           3.6            6.1           2.5
# 112  113            6.8           3.0            5.5           2.1
# 114  115            5.8           2.8            5.1           2.4
# 115  116            6.4           3.2            5.3           2.3
# 117  118            7.7           3.8            6.7           2.2
# 118  119            7.7           2.6            6.9           2.3
# 120  121            6.9           3.2            5.7           2.3
# 124  125            6.7           3.3            5.7           2.1
# 128  129            6.4           2.8            5.6           2.1
# ...

# %%
sns.scatterplot(x='SepalLengthCm',y='PetalLengthCm',data=iris)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
sns.scatterplot(x='SepalLengthCm',y='PetalLengthCm',data=iris,hue='Species')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
x=iris[['SepalLengthCm']]
y=iris[['PetalLengthCm']]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train.head()
# Out:
#      SepalLengthCm
# 26             5.0
# 91             6.1
# 142            5.8
# 66             5.6
# 67             5.8

# %%
y_train.head()
# Out:
#      PetalLengthCm
# 26             1.6
# 91             4.6
# 142            5.1
# 66             4.5
# 67             4.1

# %%
y_test.head()
# Out:
#      PetalLengthCm
# 75             4.4
# 77             5.0
# 50             4.7
# 68             4.5
# 147            5.2

# %%
x_test.head()
# Out:
#      SepalLengthCm
# 75             6.6
# 77             6.7
# 50             7.0
# 68             6.2
# 147            6.5

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=lr.predict(x_test)

# %%
y_test.head()
# Out:
#      PetalLengthCm
# 75             4.4
# 77             5.0
# 50             4.7
# 68             4.5
# 147            5.2

# %%
y_predict[0:5]
# Out:
# array([[5.21086679],
#        [5.40734153],
#        [5.99676575],
#        [4.42496784],
#        [5.01439205]])

# %%
mean_squared_error(y_test,y_predict)
# Out:
# 0.767504809611778

# %%
# Multiple Regression

# %%
x=iris[['SepalLengthCm']]
y=iris[['SepalWidthCm','PetalLengthCm','PetalWidthCm']]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=lr.predict(x_test)

# %%
y_test.head()
# Out:
#      SepalWidthCm  PetalLengthCm  PetalWidthCm
# 114           2.8            5.1           2.4
# 113           2.5            5.0           2.0
# 24            3.4            1.9           0.2
# 3             3.1            1.5           0.2
# 108           2.5            5.8           1.8

# %%
y_predict[0:5]
# Out:
# array([[3.06210738, 3.65872653, 1.15352307],
#        [3.0688449 , 3.46796465, 1.07685209],
#        [3.12948254, 1.75110767, 0.38681326],
#        [3.14295757, 1.36958389, 0.23347129],
#        [3.00146974, 5.37558351, 1.8435619 ]])

# %%
mean_squared_error(y_test,y_predict)
# Out:
# 0.42539394195851576

# %%
#  covid 19 wala example

# %%
import pandas as pd
import numpy as np  
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split  
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error

# %%
df=pd.read_csv('./datasets/covid_19_india.csv')

# %%
df.tail()
# Out:
#        Sno      Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 6381  6382  17/09/20  8:00 AM            Telengana                       -
# 6382  6383  17/09/20  8:00 AM              Tripura                       -
# 6383  6384  17/09/20  8:00 AM          Uttarakhand                       -
# 6384  6385  17/09/20  8:00 AM        Uttar Pradesh                       -
# 6385  6386  17/09/20  8:00 AM          West Bengal                       -
#
#      ConfirmedForeignNational   Cured  Deaths  Confirmed
# 6381                        -  133555    1005     165003
# 6382                        -   12956     222      20676
# 6383                        -   24432     447      35947
# 6384                        -  258573    4690     330265
# 6385                        -  184113    4123     212383

# %%
df =df[['Date','State/UnionTerritory','Cured','Deaths','Confirmed']]

# %%
df.columns=['date','state','cured','deaths','confirmed']

# %%
df.tail()
# Out:
#           date          state   cured  deaths  confirmed
# 6381  17/09/20      Telengana  133555    1005     165003
# 6382  17/09/20        Tripura   12956     222      20676
# 6383  17/09/20    Uttarakhand   24432     447      35947
# 6384  17/09/20  Uttar Pradesh  258573    4690     330265
# 6385  17/09/20    West Bengal  184113    4123     212383

# %%
#df=df[df.date=='17/09/20']

# %%
#df

# %%
max_confirm_cases=df.sort_values(by='confirmed',ascending=False)

# %%
max_confirm_cases
# Out:
#           date        state   cured  deaths  confirmed
# 6370  17/09/20  Maharashtra  792832   30883    1121221
# 6335  16/09/20  Maharashtra  775273   30409    1097856
# 6300  15/09/20  Maharashtra  755850   29894    1077374
# 6265  14/09/20  Maharashtra  740061   29531    1060308
# 6230  13/09/20  Maharashtra  728512   29115    1037765
# ...        ...          ...     ...     ...        ...
# 981   15/04/20     Nagaland       0       0          0
# 1179  21/04/20     Nagaland       0       0          0
# 1080  18/04/20     Nagaland       0       0          0
# 1146  20/04/20     Nagaland       0       0          0
# 1047  17/04/20     Nagaland       0       0          0
#
# [6386 rows x 5 columns]

# %%
# max_deaths=df.sort_values(by='deaths',ascending=False)

# %%
max_deaths
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 max_deaths
#
# NameError: name 'max_deaths' is not defined

# %%
# max_confirm_cases=df.sort_values(by='confirmed',ascending=False)
# top_confirm_states=max_confirm_cases[0:5]
# top_confirm_states

# %%
sns.set(rc={'figure.figsize':(10,5)})
sns.barplot(x='state',y='confirmed',data=top_confirm_states,hue='state')

# %%
sns.set(rc={'figure.figsize': (10, 5)})

# Create a bar plot
sns.barplot(x='state', y='confirmed', data=top_confirm_states ,hue='state')

# Add labels and title for clarity
plt.xlabel('State')
plt.ylabel('Confirmed Cases')
plt.title('Top 5 States by Confirmed Cases')
plt.show()

# %%
# max_deaths=df.sort_values(by='deaths',ascending=False)
# top_states=max_deaths[0:5]
# top_states

# %%
sns.set(rc={'figure.figsize':(10,5)})
sns.barplot(x='state',y='deaths',data=top_states,hue='state')
plt.title('Maximum deaths as per states')
plt.xlabel('STATES')
plt.ylabel('DEATH COUNT')
plt.show()

# %%
maha=df[df.state=='Maharashtra']

# %%
df

# %%
df=pd.read_csv('./datasets/covid_19_india.csv',parse_dates=['Date'],dayfirst=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10076\1696694819.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df=pd.read_csv('./datasets/covid_19_india.csv',parse_dates=['Date'],dayfirst=True)

# %%
df
# Out:
#        Sno       Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0        1 2020-01-30  6:00 PM               Kerala                       1
# 1        2 2020-01-31  6:00 PM               Kerala                       1
# 2        3 2020-02-01  6:00 PM               Kerala                       2
# 3        4 2020-02-02  6:00 PM               Kerala                       3
# 4        5 2020-02-03  6:00 PM               Kerala                       3
# ...    ...        ...      ...                  ...                     ...
# 6381  6382 2020-09-17  8:00 AM            Telengana                       -
# 6382  6383 2020-09-17  8:00 AM              Tripura                       -
# 6383  6384 2020-09-17  8:00 AM          Uttarakhand                       -
# 6384  6385 2020-09-17  8:00 AM        Uttar Pradesh                       -
# 6385  6386 2020-09-17  8:00 AM          West Bengal                       -
#
#      ConfirmedForeignNational   Cured  Deaths  Confirmed
# ...

# %%
df=df[['Date','State/UnionTerritory','Cured','Deaths','Confirmed']]

# %%
df
# Out:
#            Date State/UnionTerritory   Cured  Deaths  Confirmed
# 0    2020-01-30               Kerala       0       0          1
# 1    2020-01-31               Kerala       0       0          1
# 2    2020-02-01               Kerala       0       0          2
# 3    2020-02-02               Kerala       0       0          3
# 4    2020-02-03               Kerala       0       0          3
# ...         ...                  ...     ...     ...        ...
# 6381 2020-09-17            Telengana  133555    1005     165003
# 6382 2020-09-17              Tripura   12956     222      20676
# 6383 2020-09-17          Uttarakhand   24432     447      35947
# 6384 2020-09-17        Uttar Pradesh  258573    4690     330265
# 6385 2020-09-17          West Bengal  184113    4123     212383
#
# [6386 rows x 5 columns]

# %%
df.columns=['date','state','cured','deaths','confirmed']

# %%
df.head()
# Out:
#         date   state  cured  deaths  confirmed
# 0 2020-01-30  Kerala      0       0          1
# 1 2020-01-31  Kerala      0       0          1
# 2 2020-02-01  Kerala      0       0          2
# 3 2020-02-02  Kerala      0       0          3
# 4 2020-02-03  Kerala      0       0          3

# %%
maha=df[df.state=='Maharashtra']

# %%
maha
# Out:
#            date        state   cured  deaths  confirmed
# 76   2020-03-09  Maharashtra       0       0          2
# 91   2020-03-10  Maharashtra       0       0          5
# 97   2020-03-11  Maharashtra       0       0          2
# 120  2020-03-12  Maharashtra       0       0         11
# 133  2020-03-13  Maharashtra       0       0         14
# ...         ...          ...     ...     ...        ...
# 6230 2020-09-13  Maharashtra  728512   29115    1037765
# 6265 2020-09-14  Maharashtra  740061   29531    1060308
# 6300 2020-09-15  Maharashtra  755850   29894    1077374
# 6335 2020-09-16  Maharashtra  775273   30409    1097856
# 6370 2020-09-17  Maharashtra  792832   30883    1121221
#
# [193 rows x 5 columns]

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x='date',y='confirmed',data=maha)
plt.title('Maharashtra confirmed cases')
plt.show()

# %%
kerala=df[df.state=='Kerala']

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x='date',y='confirmed',data=kerala,color='g')
plt.title('Kerala confirmed cases')
plt.show()
